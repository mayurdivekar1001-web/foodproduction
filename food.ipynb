# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Food_Production.csv")
df.head()
# Out:
#           Food product  Land use change  Animal Feed  Farm  Processing  \
# 0  Wheat & Rye (Bread)              0.1          0.0   0.8         0.2
# 1         Maize (Meal)              0.3          0.0   0.5         0.1
# 2        Barley (Beer)              0.0          0.0   0.2         0.1
# 3              Oatmeal              0.0          0.0   1.4         0.0
# 4                 Rice              0.0          0.0   3.6         0.1
#
#    Transport  Packging  Retail  Total_emissions  \
# 0        0.1       0.1     0.1              1.4
# 1        0.1       0.1     0.0              1.1
# 2        0.0       0.5     0.3              1.1
# 3        0.1       0.1     0.0              1.6
# 4        0.1       0.1     0.1              4.0
#
#    Eutrophying emissions per 1000kcal (gPO₄eq per 1000kcal)  ...  \
# 0                                                NaN         ...
# 1                                                NaN         ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 23 columns):
#  #   Column                                                                   Non-Null Count  Dtype
# ---  ------                                                                   --------------  -----
#  0   Food product                                                             43 non-null     object
#  1   Land use change                                                          43 non-null     float64
#  2   Animal Feed                                                              43 non-null     float64
#  3   Farm                                                                     43 non-null     float64
#  4   Processing                                                               43 non-null     float64
#  5   Transport                                                                43 non-null     float64
# ...

# %%
df.describe()
# Out:
#        Land use change  Animal Feed       Farm  Processing  Transport  \
# count        43.000000    43.000000  43.000000   43.000000  43.000000
# mean          1.260465     0.453488   3.469767    0.253488   0.195349
# std           3.357730     0.919200   7.083264    0.372475   0.158795
# min          -2.100000     0.000000   0.100000    0.000000   0.000000
# 25%           0.000000     0.000000   0.350000    0.000000   0.100000
# 50%           0.200000     0.000000   0.800000    0.100000   0.100000
# 75%           0.800000     0.000000   2.200000    0.300000   0.200000
# max          16.300000     2.900000  39.400000    1.300000   0.800000
#
#         Packging     Retail  Total_emissions  \
# count  43.000000  43.000000        43.000000
# mean    0.269767   0.069767         5.972093
# std     0.342633   0.110270        10.501753
# min     0.000000   0.000000         0.200000
# 25%     0.100000   0.000000         0.850000
# 50%     0.100000   0.000000         1.600000
# ...

# %%
df.isnull().sum()
# Out:
# Food product                                                                0
# Land use change                                                             0
# Animal Feed                                                                 0
# Farm                                                                        0
# Processing                                                                  0
# Transport                                                                   0
# Packging                                                                    0
# Retail                                                                      0
# Total_emissions                                                             0
# Eutrophying emissions per 1000kcal (gPO₄eq per 1000kcal)                   10
# Eutrophying emissions per kilogram (gPO₄eq per kilogram)                    5
# Eutrophying emissions per 100g protein (gPO₄eq per 100 grams protein)      16
# ...

# %%
df.drop(columns=["Animal Feed"],inplace=True)

# %%
df.drop(columns=["Land use change"],inplace=True)

# %%
df.drop(columns=["Scarcity-weighted water use per 100g protein (liters per 100g protein)"],inplace=True)

# %%
df.drop(columns=["Land use per 100g protein (m² per 100g protein)"],inplace=True)

# %%
df.drop(columns=["Land use per kilogram (m² per kilogram)"],inplace=True)

# %%
df.drop(columns=["Land use per 1000kcal (m² per 1000kcal)"],inplace=True)

# %%
df.drop(columns=["Greenhouse gas emissions per 100g protein (kgCO₂eq per 100g protein)"],inplace=True)

# %%
df.drop(columns=["Freshwater withdrawals per 100g protein (liters per 100g protein)"],inplace=True)

# %%
df.drop(columns=["Eutrophying emissions per 1000kcal (gPO₄eq per 1000kcal)"],inplace=True)

# %%
df.head()
# Out:
#    Food product  Farm  Processing  Transport  Packging  Retail  \
# 0            41   0.8         0.2        0.1       0.1     0.1
# 1            18   0.5         0.1        0.1       0.1     0.0
# 2             2   0.2         0.1        0.0       0.5     0.3
# 3            21   1.4         0.0        0.1       0.1     0.0
# 4            33   3.6         0.1        0.1       0.1     0.1
#
#    Total_emissions  Eutrophying emissions per kilogram (gPO₄eq per kilogram)  \
# 0              1.4                                                NaN
# 1              1.1                                                NaN
# 2              1.1                                                NaN
# 3              1.6                                              11.23
# 4              4.0                                              35.07
#
#    Eutrophying emissions per 100g protein (gPO₄eq per 100 grams protein)  \
# 0                                                NaN
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['Food product'] = label_encoder.fit_transform(df['Food product'])

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['Eutrophying emissions per kilogram (gPO₄eq per kilogram)'] = label_encoder.fit_transform(df['Eutrophying emissions per kilogram (gPO₄eq per kilogram)'])

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['Eutrophying emissions per 100g protein (gPO₄eq per 100 grams protein)'] = label_encoder.fit_transform(df['Eutrophying emissions per 100g protein (gPO₄eq per 100 grams protein)'])

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['Freshwater withdrawals per 1000kcal (liters per 1000kcal)'] = label_encoder.fit_transform(df['Freshwater withdrawals per 1000kcal (liters per 1000kcal)'])

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['Freshwater withdrawals per kilogram (liters per kilogram)'] = label_encoder.fit_transform(df['Freshwater withdrawals per kilogram (liters per kilogram)'])

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['Greenhouse gas emissions per 1000kcal (kgCO₂eq per 1000kcal)'] = label_encoder.fit_transform(df['Greenhouse gas emissions per 1000kcal (kgCO₂eq per 1000kcal)'])

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['Scarcity-weighted water use per 1000kcal (liters per 1000 kilocalories)'] = label_encoder.fit_transform(df['Scarcity-weighted water use per 1000kcal (liters per 1000 kilocalories)'])

# %%
df.head()
# Out:
#    Food product  Farm  Processing  Transport  Packging  Retail  \
# 0            41   0.8         0.2        0.1       0.1     0.1
# 1            18   0.5         0.1        0.1       0.1     0.0
# 2             2   0.2         0.1        0.0       0.5     0.3
# 3            21   1.4         0.0        0.1       0.1     0.0
# 4            33   3.6         0.1        0.1       0.1     0.1
#
#    Total_emissions  Eutrophying emissions per kilogram (gPO₄eq per kilogram)  \
# 0              1.4                                                 38
# 1              1.1                                                 38
# 2              1.1                                                 38
# 3              1.6                                                 18
# 4              4.0                                                 26
#
#    Eutrophying emissions per 100g protein (gPO₄eq per 100 grams protein)  \
# 0                                                 27
# ...

# %%
x = df.drop(columns=["Total_emissions"])
y = df["Total_emissions"]

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
xtrain = scaler.fit_transform(xtrain)
xtest = scaler.transform(xtest)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(xtrain, ytrain)
# Out:
# LinearRegression()

# %%
ypred = model.predict(xtest)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
mae = mean_absolute_error(ytest, ypred)
mse = mean_squared_error(ytest, ypred)
r2 = r2_score(ytest, ypred)

print("Mean Absolute Error:", mae)
print("Mean Squared Error:", mse)
print("R-squared Score:", r2)
# Out:
# Mean Absolute Error: 1.9905962287194368
# Mean Squared Error: 5.979330066494516
# R-squared Score: 0.902120824666332
